# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['SF', 'Composite', 'LIER', 'Seyfert', 'Ambiguous', 'Other', 'No spaxel']
HIdetectionLowSFR = [10.4, 4.2, 56.3, 1.0, 7.3, 5.2, 15.6]
HIdetectionHighSFR = [58.3, 18.8, 13.5, 6.3, 2.1, 0.0, 1.0]
HInondetectionLowSFR = [5.3, 8.4, 47.4, 1.1, 2.1, 2.1, 33.7]

HIdetectionLowSFR_error =[3.3, 2.1, 7.7, 1.0, 2.8, 2.3, 4.0]
HIdetectionHighSFR_error = [7.8, 4.4, 3.8, 2.6, 1.5, 0.0, 1.0]
HInondetectionLowSFR_error = [2.4, 3.0, 7.1, 1.1, 1.5, 1.5, 6.0]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, result = plt.subplots()

# rects1 = result.bar(x - width, HIdetectionLowSFR, width, label='HI detection Low SFR', fc="#ff00ff", ec="black", yerr=HIdetectionLowSFR_error)
# rects2 = result.bar(x, HIdetectionHighSFR, width, label='HI detection High SFR', fc="#008000", ec="black", yerr=HIdetectionHighSFR_error )
# rects3 = result.bar(x + width, HInondetectionLowSFR, width, label = 'HI non detection Low SFR', fc="#00ffff", ec="black", yerr=HInondetectionLowSFR_error)

rects1 = result.bar(x - width, HIdetectionLowSFR, width, label='HI detection Low SFR', fc=(1, 0, 0, 0.95), ec="black", yerr=HIdetectionLowSFR_error)
rects2 = result.bar(x, HIdetectionHighSFR, width, label='HI detection High SFR', fc=(0, 0, 1, 0.2), ec="black", yerr=HIdetectionHighSFR_error )
rects3 = result.bar(x + width, HInondetectionLowSFR, width, label = 'HI non detection Low SFR', fc=(0, 0, 0, 0.05), ec="black", yerr=HInondetectionLowSFR_error)

# rects1 = result.bar(x - width, HIdetectionLowSFR, width, label='HI detection Low SFR', hatch='...', fc="white", ec="black", yerr=HIdetectionLowSFR_error)
# rects2 = result.bar(x, HIdetectionHighSFR, width, label='HI detection High SFR', hatch='///', fc="white", ec="black", yerr=HIdetectionHighSFR_error )
# rects3 = result.bar(x + width, HInondetectionLowSFR, width, label = 'HI non detection Low SFR', hatch='**', fc="white", ec="black", yerr=HInondetectionLowSFR_error)

# rects1 = result.bar(x - width, HIdetectionLowSFR, width, label='HI detection Low SFR', yerr=HIdetectionLowSFR_error)
# rects2 = result.bar(x, HIdetectionHighSFR, width, label='HI detection High SFR', yerr=HIdetectionHighSFR_error )
# rects3 = result.bar(x + width, HInondetectionLowSFR, width, label = 'HI non detection Low SFR', yerr=HInondetectionLowSFR_error)

# Add some text for labels, title and custom x-axis tick labels, etc.
result.set_ylabel('Percentages')
result.set_title('Classification of ionization sources')
result.set_xticks(x)
result.set_xticklabels(labels)
result.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        result.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 1.5),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)

fig.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 2
eLIER = (14.6, 22.1)
cLIER = (41.7, 25.3)
eLIERerr = (3.9, 4.8)
cLIERerr = (6.6, 5.2)
ind = np.arange(N)    # the x locations for the groups
width = 0.40       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, eLIER, width, yerr=eLIERerr, fc=(1, 0, 0, 0.95), ec="black")
p2 = plt.bar(ind, cLIER, width, bottom=eLIER, yerr=cLIERerr, fc=(0, 0, 1, 0.2), ec="black")

# p1 = plt.bar(ind, eLIER, width, yerr=eLIERerr)
# p2 = plt.bar(ind, cLIER, width, bottom=eLIER, yerr=cLIERerr)

plt.ylabel('Percentage')
plt.title('LIERs Proportion')
plt.xticks(ind, ('HI Detection Low SFR', 'HI Non-Detection Low SFR'))
plt.yticks(np.arange(0, 61, 10))
plt.legend((p1[0], p2[0]), ('eLIER', 'cLIER'))

plt.show()
