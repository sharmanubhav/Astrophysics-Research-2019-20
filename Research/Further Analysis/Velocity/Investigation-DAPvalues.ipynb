# %%
import numpy
import math
from astropy.io import fits
from astropy.table import Table
from matplotlib.colors import LogNorm
from astropy.modeling import models, fitting

#set up matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DAP_file = fits.open("dapall-v2_7_1-2.4.1.fits", memmap=True)
DAP_table = Table(DAP_file[1].data)

# %%
sample_space = ['7957-12701                      ', '7958-3704                       ', '7992-9101                       ', '8148-6102                       ', '8439-1902                       ', '8446-3702                       ', '8935-3704                       ', '9183-3702                       ', '9892-3702                       ', '8243-3701                       ', '8453-3703                       ', '8483-1902                       ', '8948-6102                       ', '8554-12704                      ', '8248-3701                       ', '8551-9101                       ', '8588-3704                       ', '8717-6101                       ', '8942-6102                       ', '9492-6104                       ', '10001-3704                      ', '10220-9101                      ', '10499-3701                      ', '10499-6102                      ', '10516-3701                      ', '7957-6102                       ', '7960-3702                       ', '7979-3701                       ', '7991-3704                       ', '7991-6101                       ', '7991-6104                       ', '7993-12704                      ', '8134-6102                       ', '8135-6103                       ', '8137-1901                       ', '8137-3703                       ', '8138-3702                       ', '8139-6101                       ', '8145-3702                       ', '8150-6102                       ', '8155-3702                       ', '8239-3701                       ', '8244-6104                       ', '8248-6104                       ', '8249-12705                      ', '8252-12702                      ', '8255-1902                       ', '8313-12704                      ', '8313-6102                       ', '8317-3702                       ', '8322-12705                      ', '8326-1902                       ', '8326-3701                       ', '8443-6102                       ', '8446-9101                       ', '8450-6101                       ', '8452-6102                       ', '8453-3702                       ', '8456-1902                       ', '8458-9102                       ', '8461-1902                       ', '8484-1901                       ', '8484-3702                       ', '8550-12701                      ', '8588-12701                      ', '8601-6101                       ', '8623-6102                       ', '8626-3701                       ', '8626-3704                       ', '8712-12704                      ', '8712-12705                      ', '8715-6104                       ', '8719-3701                       ', '8939-12703                      ', '8948-12702                      ', '8985-12702                      ', '8989-9101                       ', '8992-6103                       ', '8997-6104                       ', '8999-6102                       ', '9036-9101                       ', '9040-6101                       ', '9046-12702                      ', '9086-6103                       ', '9088-6103                       ', '9095-1902                       ', '9182-6104                       ', '9184-12704                      ', '9196-12701                      ', '9490-12705                      ', '9500-12704                      ', '9506-6104                       ', '9511-1901                       ', '9513-3702                       ', '9514-3704                       ', '9864-6101                       ', '9865-3704                       ']

sample = [x.strip() for x in sample_space]

control_1 = ['10517-3702', '8252-12701', '8317-6101', '8338-12704', '8552-6101', '8711-6103', '8995-12702', '10517-9101', '8149-9101', '8447-1901', '8716-12703', '8981-12705', '8989-12705', '10499-3702', '8155-3703', '8438-6102', '9497-3703', '10221-9101', '10503-12703', '10512-12702', '10512-6102', '10512-9102', '10514-12705', '10514-9102', '10516-12701', '10516-6104', '7443-6102', '7495-12704', '7975-9102', '7992-6104', '7993-12701', '7993-1902', '8078-12701', '8078-6103', '8080-6104', '8084-12703', '8137-12703', '8140-3701', '8141-12703', '8149-3704', '8241-12703', '8241-6102', '8243-12704', '8244-6102', '8315-9102', '8325-12703', '8439-12703', '8443-6103', '8449-12702', '8482-12705', '8549-12704', '8550-12704', '8553-9101', '8554-12702', '8555-12705', '8567-3701', '8588-12704', '8591-12705', '8592-6102', '8601-9101', '8604-12701', '8611-9102', '8612-12703', '8624-9102', '8625-12703', '8626-3703', '8713-9102', '8715-12701', '8932-3701', '8943-1901', '8944-12703', '8944-9101', '8982-9101', '8983-3703', '8989-12702', '8990-9102', '8992-12702', '8993-12702', '8996-12701', '9000-12702', '9028-6101', '9029-12702', '9037-12703', '9040-6104', '9091-9101', '9182-9102', '9194-12701', '9195-3703', '9497-12703', '9501-12701', '9505-6104', '9509-3702', '9509-6103', '9511-12704', '9887-12701', '9888-9101', '9889-6103']

control_2 = ['10220-1902', '10503-6103', '7495-6103', '8156-1901', '8317-3704', '8322-1902', '8325-1902', '8449-1902', '8451-1901', '8553-3701', '8940-3702', '9049-1902', '9485-12704', '9509-1902', '9862-12704', '7992-3701', '8086-3701', '8243-3702', '8319-3702', '8329-1902', '8456-3704', '8940-3701', '8978-3704', '8980-6103', '9028-3702', '9490-3703', '9491-1901', '8154-12702', '10217-3704', '8140-1901', '8259-6102', '8450-12703', '8950-3702', '9037-3701', '9043-1901', '9507-9102', '10216-3704', '10217-6102', '10221-6104', '10504-3703', '10514-6104', '10516-3704', '10519-1901', '7443-12701', '7957-1901', '7975-6102', '7979-6102', '8077-3701', '8077-6101', '8078-6102', '8081-6102', '8139-9102', '8141-12705', '8141-6101', '8143-6104', '8158-3701', '8158-6102', '8249-6104', '8313-6101', '8330-9102', '8439-12702', '8443-3702', '8444-9101', '8448-6103', '8450-6104', '8484-6102', '8547-3703', '8550-6101', '8603-3704', '8615-3704', '8625-12701', '8626-12701', '8656-3702', '8940-6104', '8950-6103', '8984-3703', '8984-6104', '8992-6102', '8992-9102', '8997-6101', '9026-12705', '9042-6101', '9088-3702', '9090-3702', '9183-3704', '9193-6101', '9501-3702', '9508-6102', '9509-3704', '9511-6102', '9863-3702', '9866-1902', '9881-12704', '9882-9101', '9886-1901', '9886-9102', '9889-3701']

print(len(sample))
print(len(control_1))
print(len(control_2))
# Out:
# 97
# 97
# 97

# %%
Plateifu= numpy.array(DAP_table['PLATEIFU']) # All Plateifu

# print(len(Plateifu))
# print(len(set(Plateifu)))

HA_CLIP= numpy.array(DAP_table ['HA_GSIGMA_HI_CLIP'])   # All HA_GSIGMA_HI_CLIP
STELLAR_CLIP= numpy.array(DAP_table ['STELLAR_VEL_HI_CLIP'])   # All HA_GSIGMA_HI_CLIP
HA_1RE= numpy.array(DAP_table ['HA_GSIGMA_1RE'])   # All HA_GSIGMA_1RE
STELLAR_1RE= numpy.array(DAP_table ['STELLAR_SIGMA_1RE'])   # All STELLAR_SIGMA_1RE
BIN_TYPE = numpy.array(DAP_table ['DAPTYPE'])                # BIN TYPE
MANGA_ID = numpy.array(DAP_table ['MANGAID'])                # MANGA ID


# print(Plateifu.tolist())

def values(parameter_array, plateifu_array):
    indices = []
    for index, plateifu in enumerate(Plateifu):
        if plateifu in plateifu_array and BIN_TYPE[index] == 'HYB10-MILESHC-MASTARHC':
            indices.append(index)
#     print(len(indices))
    value = [parameter_array[x] for x in indices]
#     plateifu = [Plateifu[x] for x in indices]
#     print(len(plateifu))
#     print(len(plateifu_array))
#     z = [y for y in plateifu_array if y not in plateifu]
#     print(z)
#     print(len(z))

    return value

def histograms(title, parameter):
    plt.xlabel(title)
    plt.ylabel("Frequency")
    plt.title("Histogram showing " + title)
    plt.hist(values(parameter, sample), bins=15, alpha=0.4, label='Sample: HI detection Low SFR')
    plt.hist(values(parameter, control_1), bins=15, alpha=0.4, label='Control I: HI detection High SFR', hatch='...', fc="white", ec="black")
    plt.legend()
    plt.show()
    plt.xlabel(title)
    plt.ylabel("Frequency")
    plt.title("Histogram showing " + title)
    plt.hist(values(parameter, sample), bins=15, alpha=0.4, label='Sample: HI detection Low SFR')
    plt.hist(values(parameter, control_2), bins=15, alpha=0.4, label='Control II: HI non-detection Low SFR', hatch='...', fc="white", ec="black")
    plt.legend()
    plt.show()
    
# histograms('HA_GSIGMA_HI_CLIP', HA_CLIP)
# histograms('STELLAR_VEL_HI_CLIP', STELLAR_CLIP)
# histograms('HA_GSIGMA_1RE', HA_1RE)
# histograms('STELLAR_SIGMA_1RE', STELLAR_1RE)

# print(values(MANGA_ID, sample))
# print(values(MANGA_ID, control_1))
# print(values(MANGA_ID, control_2))
# Out:
# ['1-23891', '1-24018', '1-24148', '1-115401', '1-339028', '1-378148', '1-338677', '1-338746', '1-338220', '1-137853', '1-567187', '1-47862', '1-259117', '1-46757', '1-156061', '1-167555', '1-147521', '1-172948', '1-235530', '1-235587', '1-94228', '1-94027', '1-94029', '1-247430', '1-619066', '1-210962', '1-248289', '1-569216', '1-561039', '1-546816', '1-22412', '1-594528', '1-594602', '1-95093', '1-24295', '1-24418', '1-177528', '1-178824', '1-38543', '1-201314', '1-548190', '1-166646', '1-217520', '1-48223', '1-167334', '1-351919', '1-256210', '1-491047', '1-121697', '1-378526', '1-379741', '1-379708', '1-218412', '1-148954', '1-173898', '1-298868', '1-247661', '1-547341', '1-121209', '1-72350', '1-412544', '1-72211', '1-386302', '1-576182', '1-149471', '1-556831', '1-153103', '1-174947', '1-422969', '1-456708', '1-418071', '1-418228', '1-148987', '1-605482', '1-389238', '1-213603', '1-415939', '1-376429', '1-265801', '1-197280', '1-246542', '1-595146', '1-575232', '1-42862', '1-42230', '1-42195', '1-145791', '1-481320', '1-481779', '1-201969', '1-299684', '1-299468', '1-60689', '1-296414', '1-633819', '1-295446', '1-318128']
# ['12-180432', '12-129618', '1-114500', '1-338796', '1-43702', '1-604937', '1-138087', '1-47136', '1-259195', '1-47291', '1-605884', '1-542392', '1-134599', '1-321962', '1-235398', '1-134954', '1-402649', '1-419536', '1-211063', '1-23784', '1-210881', '1-236776', '1-22662', '1-569116', '1-96077', '1-135641', '1-24440', '1-351566', '1-36832', '1-37213', '1-38541', '1-145884', '1-164153', '1-71974', '1-109378', '1-548157', '1-488790', '1-491218', '1-379571', '1-460862', '1-460288', '1-379277', '1-245404', '1-246470', '1-392007', '1-135093', '1-91016', '1-457811', '1-24161', '1-269085', '1-25740', '1-603039', '1-38029', '1-72203', '1-606955', '1-389479', '1-277300', '1-605075', '1-218233', '1-385070', '1-149556', '1-188218', '1-456306', '1-37400', '1-229673', '1-556805', '1-387155', '1-175169', '1-175185', '1-627397', '1-458396', '1-149610', '1-614392', '1-605353', '1-615921', '1-247758', '1-316920', '1-603309', '1-581847', '1-229796', '1-403958', '1-474575', '1-585668', '1-77704', '1-78627', '1-78665', '1-299674', '1-605611', '1-77060', '1-605657', '1-60653', '1-78868', '1-587259', '1-296599', '1-375061', '1-265247', '1-559160']
# ['12-98126', '12-129602', '1-115435', '1-114145', '1-38033', '1-43679', '1-44117', '1-44100', '1-44479', '1-137845', '1-257627', '1-234004', '1-629695', '1-284230', '1-47302', '1-155926', '1-256125', '1-487452', '1-235257', '1-94168', '1-594483', '1-248389', '1-634477', '1-260481', '1-22347', '1-210701', '1-180012', '1-24425', '1-38764', '1-37036', '1-36977', '1-36890', '1-229017', '1-167141', '1-488575', '1-491229', '1-492524', '1-583694', '1-52701', '1-245869', '1-135003', '1-236039', '1-456505', '1-456937', '1-375134', '1-94696', '1-295359', '1-90984', '1-24003', '1-269212', '1-109152', '1-71108', '1-37797', '1-383612', '1-163992', '1-218077', '1-584801', '1-122141', '1-230050', '1-230100', '1-385080', '1-149470', '1-149512', '1-149541', '1-122054', '1-382806', '1-423101', '1-458138', '1-395734', '1-299016', '1-298940', '1-213422', '1-421972', '1-199415', '1-265632', '1-455918', '1-523188', '1-575202', '1-374844', '1-31500', '1-382355', '1-412043', '1-458682', '1-298693', '1-78021', '1-146605', '1-456920', '1-183195', '1-60707', '1-523057', '1-183745', '1-272299', '1-300968', '1-375863', '1-375679', '1-440254', '1-297190']

# %%
import numpy
import math
from astropy.io import fits
from astropy.table import Table
from matplotlib.colors import LogNorm
from astropy.modeling import models, fitting

DAP_file = fits.open("dapall-v2_7_1-2.4.1.fits", memmap=True)
DAP_table = Table(DAP_file[1].data)

Plateifu= numpy.array(DAP_table['PLATEIFU']) # All Plateifu

print(len(Plateifu))
print(len(set(Plateifu)))
# Out:
# 24390
# 8130
